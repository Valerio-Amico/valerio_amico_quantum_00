# %%
from sympy import *
import funzioni02 as f2
import numpy as np
from sympy.physics.quantum import TensorProduct as Tp
from sympy.physics.quantum.dagger import Dagger as dg

# %%
a, e, c, s = symbols("a e c s")  # a=2t/N

Id=eye(2)

X=Matrix([
    [0,1],
    [1,0]
])

Y=Matrix([
    [0,-1j],
    [1j,0]
])

Z=Matrix([
    [1,0],
    [0,-1]
])

A=Matrix([
    [e**(-1j*a),0,0,0],
    [0,cos(a),-1j*sin(a),0],
    [0,-1j*sin(a),cos(a),0],
    [0,0,0,e**(-1j*a)]
])

# %%
H1=Tp(A,Id)
H2=Tp(Id,A)

# %%
H1
# Out:
# Matrix([
# [e**(-1.0*I*a),             0,             0,             0,             0,             0,             0,             0],
# [            0, e**(-1.0*I*a),             0,             0,             0,             0,             0,             0],
# [            0,             0,        cos(a),             0, -1.0*I*sin(a),             0,             0,             0],
# [            0,             0,             0,        cos(a),             0, -1.0*I*sin(a),             0,             0],
# [            0,             0, -1.0*I*sin(a),             0,        cos(a),             0,             0,             0],
# [            0,             0,             0, -1.0*I*sin(a),             0,        cos(a),             0,             0],
# [            0,             0,             0,             0,             0,             0, e**(-1.0*I*a),             0],
# ...

# %%
H2
# Out:
# Matrix([
# [e**(-1.0*I*a),             0,             0,             0,             0,             0,             0,             0],
# [            0,        cos(a), -1.0*I*sin(a),             0,             0,             0,             0,             0],
# [            0, -1.0*I*sin(a),        cos(a),             0,             0,             0,             0,             0],
# [            0,             0,             0, e**(-1.0*I*a),             0,             0,             0,             0],
# [            0,             0,             0,             0, e**(-1.0*I*a),             0,             0,             0],
# [            0,             0,             0,             0,             0,        cos(a), -1.0*I*sin(a),             0],
# [            0,             0,             0,             0,             0, -1.0*I*sin(a),        cos(a),             0],
# ...

# %%
H=simplify(H1*H2)
H
# Out:
# Matrix([
# [e**(-2.0*I*a),                    0,                           0,                           0,                           0,                           0,                    0,             0],
# [            0, e**(-1.0*I*a)*cos(a), -1.0*I*e**(-1.0*I*a)*sin(a),                           0,                           0,                           0,                    0,             0],
# [            0,      -0.5*I*sin(2*a),                   cos(a)**2,                           0, -1.0*I*e**(-1.0*I*a)*sin(a),                           0,                    0,             0],
# [            0,                    0,                           0,        e**(-1.0*I*a)*cos(a),                           0,             -0.5*I*sin(2*a),       -1.0*sin(a)**2,             0],
# [            0,       -1.0*sin(a)**2,             -0.5*I*sin(2*a),                           0,        e**(-1.0*I*a)*cos(a),                           0,                    0,             0],
# ...

# %%
#B, D = H.diagonalize()

# %%
U=Matrix([
    [H[3*8+3],H[3*8+5],H[3*8+6]],
    [H[5*8+3],H[5*8+5],H[5*8+6]],
    [H[6*8+3],H[6*8+5],H[6*8+6]]
])

# %%
U
# Out:
# Matrix([
# [       e**(-1.0*I*a)*cos(a),             -0.5*I*sin(2*a),       -1.0*sin(a)**2],
# [-1.0*I*e**(-1.0*I*a)*sin(a),                   cos(a)**2,      -0.5*I*sin(2*a)],
# [                          0, -1.0*I*e**(-1.0*I*a)*sin(a), e**(-1.0*I*a)*cos(a)]])

# %%
B1, D1 = U.diagonalize()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/pyEnv/lib/python3.8/site-packages/sympy/core/assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/pyEnv/lib/python3.8/site-packages/sympy/core/assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'finite'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
